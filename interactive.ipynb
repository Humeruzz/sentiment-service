# %%
import requests
r = requests.post("http://localhost:8000/predict", json={"text": "Das ist super", "lang": "de"})
print(r.json())
# Out:
# {'text': 'Das ist super', 'label': 'positive', 'confidence': 0.9659, 'lang': 'de'}

# %%
r = requests.get("http://localhost:8000/health")
print(r.json())
# Out:
# {'status': 'ok', 'model_loaded': True}

# %%
r = requests.get("http://localhost:8000/metadata")
print(r.json())
# Out:
# {'run_id': '9e6b685904bf48dfa9b00670f774a9ea', 'model_version': '1', 'registered_at': '2026-04-23T19:03:35.801018+00:00'}
